# %%
import Robogame as rg
import networkx as nx
import altair as alt
import time, json
import pandas as pd
import numpy as np
from pyvis.network import Network

# %% [markdown]
# To start a game server go into the server directory. Make sure you have flask and networkx installed (```conda install networkx flask flask-cors requests scipy``` should do it).
#
# To start a server do:
#
# ```python api.py [-d directoryforgame] [-s] [-t1s T1Secret] [-t2s T2Secret] gameid```
#
# gameid is the the prefix of all the game files (the examples we gave you are examplematch1, examplematch2, examplematch3.
#
# ```
# -d/--directory is an optional directory. For example, we put the examplematch1 files in the example1 directory
# -s/--simulated tells us whether to simulate team 2
# -t1s/--team1secret is Team 1's secret. If you don't specify this, the server will give you one
# -t2s/--team1secret is Team 2's secret. This is ignored if you use -s. If you don't specify this, the server will give you one
# -m/--matchsave is a log file to save the game in, a random log name will be used if you don't specify this
# ```
#
# Here's a simple game:
#
# ```python api.py -d ./example1 -s -t1s bob examplematch1```
#
# We're using the examplematch1 files in the example1 directory, simulating player 2 and team 1's secret is 'bob' (that's us)

# %%
# create a game connection using bob as the "secret" key for your team (this is what you're given by the server)
game = rg.Robogame("bob")

# the default is to the localhost on port 5000, if you want something else you can do:
# game = rg.Robogame("bob",server="12.12.31.1",port=2324)

# %%
# tell the server we're ready to go
game.setReady()
# Out:
# {'Result': 'OK'}

# %%
# get the current game time
# there is a buffer before the game actually starts once both teams are ready

# wait for both players to be ready
while(True):
    gametime = game.getGameTime()
    
    if ('Error' in gametime):
        print("Error"+str(gametime))
        break
    
    timetogo = gametime['gamestarttime_secs'] - gametime['servertime_secs']

    if (timetogo <= 0):
        print("Let's go!")
        break
        
    print("waiting to launch... game will start in " + str(int(timetogo)))
    time.sleep(1) # sleep 1 second at a time, wait for the game to start
# Out:
# waiting to launch... game will start in 9
# waiting to launch... game will start in 8
# waiting to launch... game will start in 7
# waiting to launch... game will start in 6
# waiting to launch... game will start in 5
# waiting to launch... game will start in 4
# waiting to launch... game will start in 3
# waiting to launch... game will start in 2
# waiting to launch... game will start in 1
# waiting to launch... game will start in 0
# Let's go!

# %%
# check the current game time
game.getGameTime()
# Out:
# {'curtime': 0.14,
#  'gameendtime_secs': 1702105286.926878,
#  'gamestarttime_secs': 1702104686.926878,
#  'servertime_secs': 1702104687.785047,
#  'unitsleft': 99.86}

# %%
# get the robot data (note that the bets column are the guesses your team has associated with the robots at the moment)
robots = game.getRobotInfo()

# if you want this in json format, do:
# robots = game.getRobotInfo(js=True)

# %%
# see what's inside
robots.sample(10)
# Out:
#       id                    name  expires  winner  Productivity winningTeam  \
# 110  110    Pulllift Botberg Jr.      NaN      -2           NaN  Unassigned
# 67    67       Waterminer Botsky     35.0      -2           NaN  Unassigned
# 140  140     Pushwaller Boterson      NaN      -2           NaN  Unassigned
# 112  112    Thumpdigger Botson I      NaN      -2           NaN  Unassigned
# 16    16     Stonewidget Botberg     30.0      -2           NaN  Unassigned
# 25    25   Extravator Botski Jr.     41.0      -2           NaN  Unassigned
# 29    29       Extraborer Botsky     48.0      -2           NaN  Unassigned
# 27    27      Extrawalker Botski     69.0      -2           NaN  Unassigned
# 45    45  Pullpulverizer Botchik     85.0      -2           NaN  Unassigned
# 128  128  Stonepulverizer Botsky      NaN      -2           NaN  Unassigned
#
#      bets
# 110    -1
# 67     -1
# 140    -1
# 112    -1
# 16     -1
# 25     -1
# 29     -1
# 27     -1
# 45     -1
# 128    -1

# %%
# let's plot the distribution of expirations
alt.Chart(robots).mark_bar().encode(
    alt.X("expires:Q", bin=True),
    y='count()',
)
# Out:
# alt.Chart(...)

# %%
# grab the networks
network = game.getNetwork()
links = network['links']
df = pd.DataFrame(links, columns=['source', 'target'])
df
# Out:
#      source  target
# 0         0       1
# 1         0      99
# 2         0       2
# 3         0      98
# 4         1       2
# ..      ...     ...
# 195      95      97
# 196      96      98
# 197      97      98
# 198      97      99
# 199      98      99
#
# [200 rows x 2 columns]

# %%
G = nx.from_pandas_edgelist(df, source='source', target='target')
node_winner_values = {node: robots.loc[robots['id'] == node, 'winner'].values[0] for node in G.nodes}
node_winner_values
# Out:
# {0: -2,
#  1: -2,
#  99: -2,
#  2: -2,
#  98: -2,
#  3: -2,
#  61: -2,
#  4: -2,
#  5: -2,
#  6: -2,
#  7: -2,
#  8: -2,
#  9: -2,
#  10: -2,
#  11: -2,
#  37: -2,
#  13: -2,
#  57: -2,
#  12: -2,
#  14: -2,
#  15: -2,
#  69: -2,
#  16: -2,
#  39: -2,
#  17: -2,
#  18: -2,
#  19: -2,
#  20: -2,
#  21: -2,
#  22: -2,
#  23: -2,
#  24: -2,
#  25: -2,
#  26: -2,
#  27: -2,
#  71: -2,
#  28: -2,
#  44: -2,
#  29: -2,
#  65: -2,
#  30: -2,
#  31: -2,
#  64: -2,
#  70: -2,
#  33: -2,
#  32: -2,
#  34: -2,
#  35: -2,
#  36: -2,
#  38: -2,
#  40: -2,
#  41: -2,
#  93: -2,
#  66: -2,
#  42: -2,
#  43: -2,
#  45: -2,
#  46: -2,
#  96: -2,
#  47: -2,
#  48: -2,
#  49: -2,
#  50: -2,
#  51: -2,
#  87: -2,
#  52: -2,
#  53: -2,
#  54: -2,
#  95: -2,
#  55: -2,
#  56: -2,
#  58: -2,
#  59: -2,
#  67: -2,
#  60: -2,
#  62: -2,
#  63: -2,
#  72: -2,
#  68: -2,
#  73: -2,
#  74: -2,
#  75: -2,
#  76: -2,
#  77: -2,
#  78: -2,
#  79: -2,
#  80: -2,
#  81: -2,
#  82: -2,
#  83: -2,
#  84: -2,
#  85: -2,
#  86: -2,
#  88: -2,
#  89: -2,
#  90: -2,
#  91: -2,
#  92: -2,
#  94: -2,
#  97: -2}

# %%
# Count occurrences for each source and target separately
count_source = df.groupby('source')['target'].count().reset_index(name='count_source')
count_target = df.groupby('target')['source'].count().reset_index(name='count_target')

# Merge the counts based on the target column
friends_counts = pd.merge(count_source, count_target, how='outer', left_on='source', right_on='target')

# Fill NaN values with 0 (when a source or target only appears in one column)
friends_counts = friends_counts.fillna(0)

# Sum the counts to get the total count for each source or target
friends_counts['counts'] = friends_counts['count_source'] + friends_counts['count_target']

friends_counts = pd.DataFrame(friends_counts)
# Display the resulting DataFrame

normalized_counts = friends_counts['counts'] / friends_counts['counts'].max()
rounded_counts = (normalized_counts * 100).round().astype(int)
rounded_counts.loc[44]
# Out:
# 100

# %%
net = Network(notebook = True)
for node in G.nodes:
    net.add_node(node, label=str(node))
# Out:
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.

# %%
# use the networkx package to parse it and plot it
socialnet = nx.node_link_graph(network)
nx.draw_kamada_kawai(socialnet)

# %%
network.keys()
# Out:
# dict_keys(['directed', 'graph', 'links', 'multigraph', 'nodes'])

# %%
# get the genealogy tree
tree = game.getTree()
# Out:
# {'children': [{'children': [{'children': [{'children': [{'children': [{'children': [{'id': 11},
#             {'id': 32},
#             {'id': 26}],
#            'id': 100},
#           {'children': [{'id': 30}, {'id': 62}, {'id': 22}, {'id': 54}],
#            'id': 116},
#           {'id': 99},
#           {'id': 42}],
#          'id': 127},
#         {'id': 56},
#         {'id': 6}],
#        'id': 131},
#       {'children': [{'children': [{'children': [{'children': [{'id': 8},
#               {'id': 36},
#               {'id': 90}],
#              'id': 101},
#             {'id': 66},
#             {'id': 95},
#             {'id': 12}],
#            'id': 106},
#           {'id': 83},
#           {'id': 33}],
#          'id': 126},
#         {'children': [{'children': [{'id': 73}, {'id': 76}], 'id': 104},
#           {'children': [{'id': 60}, {'id': 70}], 'id': 110},
#           {'children': [{'children': [{'id': 13}, {'id': 77}, {'id': 5}],
#              'id': 103},
#             {'id': 55}],
#            'id': 113},
#           {'id': 96}],
#          'id': 130},
#         {'id': 63},
#         {'id': 10}],
#        'id': 135}],
#      'id': 139},
#     {'id': 40}],
#    'id': 141},
#   {'children': [{'children': [{'id': 47}, {'id': 19}], 'id': 105}, {'id': 98}],
#    'id': 142},
#   {'children': [{'children': [{'id': 46}, {'id': 81}], 'id': 112},
#     {'children': [{'children': [{'children': [{'id': 45},
#           {'id': 67},
#           {'id': 4},
#           {'id': 59}],
#          'id': 120},
#         {'id': 21},
#         {'id': 25},
#         {'id': 43}],
#        'id': 122},
#       {'children': [{'id': 48}, {'id': 34}], 'id': 136}],
#      'id': 145},
#     {'children': [{'children': [{'id': 27}, {'id': 94}], 'id': 128},
#       {'children': [{'children': [{'children': [{'id': 61},
#             {'id': 69},
#             {'id': 14}],
#            'id': 119},
#           {'id': 35},
#           {'id': 91},
#           {'id': 39}],
#          'id': 123},
#         {'children': [{'children': [{'children': [{'id': 89},
#               {'id': 29},
#               {'id': 58},
#               {'id': 24}],
#              'id': 108},
#             {'id': 87},
#             {'id': 28},
#             {'id': 75}],
#            'id': 111},
#           {'id': 78},
#           {'id': 85},
#           {'id': 38}],
#          'id': 132},
#         {'children': [{'id': 49}, {'id': 31}], 'id': 138},
#         {'id': 84}],
#        'id': 143},
#       {'children': [{'children': [{'children': [{'id': 82}, {'id': 79}],
#            'id': 121},
#           {'children': [{'children': [{'children': [{'children': [{'id': 23},
#                   {'id': 86},
#                   {'id': 71},
#                   {'id': 41}],
#                  'id': 107},
#                 {'id': 93},
#                 {'id': 80}],
#                'id': 109},
#               {'id': 7}],
#              'id': 118},
#             {'id': 97}],
#            'id': 124},
#           {'children': [{'children': [{'id': 16}, {'id': 15}, {'id': 50}],
#              'id': 117},
#             {'id': 52},
#             {'id': 0}],
#            'id': 125},
#           {'id': 68}],
#          'id': 129},
#         {'children': [{'children': [{'children': [{'id': 3}, {'id': 1}],
#              'id': 114},
#             {'id': 17}],
#            'id': 133},
#           {'children': [{'children': [{'id': 44}, {'id': 88}, {'id': 18}],
#              'id': 102},
#             {'id': 74}],
#            'id': 134},
#           {'children': [{'children': [{'id': 2}, {'id': 64}, {'id': 57}],
#              'id': 115},
#             {'id': 72}],
#            'id': 137},
#           {'id': 53}],
#          'id': 140},
#         {'id': 65},
#         {'id': 9}],
#        'id': 144},
#       {'id': 37}],
#      'id': 146},
#     {'children': [{'id': 51}, {'id': 92}, {'id': 20}], 'id': 147}],
#    'id': 148}],
#  'id': 149}

# %%
import igraph
from igraph import Graph, EdgeSeq

# %%
# use networkx to parse and plot it
genealogy = nx.tree_graph(tree)
nx.draw_kamada_kawai(genealogy)

# %%
# we can get hints every 6 seconds or so, let's grab a few rounds of hints

# note that you can now do getHints(hintstart=4)  where the number indicates
# from when to give you the hints (so this will give you everything from time
# unit 4 until now)
for i in np.arange(0,3):
    # this will give us just the new hints, but the object will store everything we've seen
    hints = game.getHints()
    if ('parts' in hints):
        print('we got '+str(len(hints['parts']))+' part hints')
    time.sleep(6)


# get all the hints we've collected
predHints = game.getAllPredictionHints()
partHints = game.getAllPartHints()
# Out:
# we got 246 part hints
# we got 12 part hints
# we got 12 part hints

# %%
predHints
# Out:
# [{'id': 122, 'time': 43, 'value': 17.54434465521253},
#  {'id': 4, 'time': 54, 'value': 64.68827140313108},
#  {'id': 132, 'time': 11, 'value': 43.42847967874872},
#  {'id': 103, 'time': 83, 'value': 94.43283157597662},
#  {'id': 110, 'time': 44, 'value': 8.429225510191781},
#  {'id': 135, 'time': 83, 'value': 47.80717305055969},
#  {'id': 95, 'time': 41, 'value': 27.001268290263504},
#  {'id': 78, 'time': 22, 'value': 9.182425263226362},
#  {'id': 46, 'time': 10, 'value': 51.01851798586765},
#  {'id': 56, 'time': 61, 'value': 47.51385610262066},
#  {'id': 78, 'time': 26, 'value': 2.7912446104389077},
#  {'id': 34, 'time': 11, 'value': 0.657397734808444},
#  {'id': 81, 'time': 70, 'value': 59.50308114563539},
#  {'id': 54, 'time': 37, 'value': 34.508801656497475},
#  {'id': 12, 'time': 99, 'value': 89.72522061068959},
#  {'id': 47, 'time': 99, 'value': 59.51953389012444},
#  {'id': 149, 'time': 66, 'value': 99.38381044710364},
#  {'id': 43, 'time': 100, 'value': 71.59938483937017},
#  {'id': 117, 'time': 48, 'value': 23.154884735353253},
#  {'id': 73, 'time': 22, 'value': 2.4745914391239},
#  {'id': 124, 'time': 6, 'value': 28.51471216976729},
#  {'id': 21, 'time': 6, 'value': 58.614698122210186},
#  {'id': 123, 'time': 10, 'value': 43.35050753663728},
#  {'id': 120, 'time': 64, 'value': 99.60229534363852},
#  {'id': 37, 'time': 23, 'value': 17.028703460904822},
#  {'id': 126, 'time': 65, 'value': 62.11171203484582},
#  {'id': 0, 'time': 2, 'value': 39.23663055870526},
#  {'id': 81, 'time': 1, 'value': 100.0},
#  {'id': 21, 'time': 41, 'value': 4.683320089411932},
#  {'id': 149, 'time': 97, 'value': 58.885410451932},
#  {'id': 96, 'time': 84, 'value': 46.64402367140181},
#  {'id': 50, 'time': 86, 'value': 98.0405431433023},
#  {'id': 97, 'time': 14, 'value': 12.082890086220026},
#  {'id': 47, 'time': 44, 'value': 25.114099996972385},
#  {'id': 112, 'time': 54, 'value': 45.91194499765379},
#  {'id': 33, 'time': 90, 'value': 13.322459066898524},
#  {'id': 92, 'time': 19, 'value': 11.981115431314867},
#  {'id': 55, 'time': 32, 'value': 1.1261395701746375},
#  {'id': 27, 'time': 85, 'value': 69.22903828043947},
#  {'id': 101, 'time': 35, 'value': 12.890497506115384},
#  {'id': 21, 'time': 29, 'value': 2.628680648844148},
#  {'id': 57, 'time': 100, 'value': 100.0},
#  {'id': 73, 'time': 50, 'value': 31.060232076983112},
#  {'id': 145, 'time': 15, 'value': 33.204106570728314},
#  {'id': 131, 'time': 99, 'value': 65.94684636357331},
#  {'id': 12, 'time': 26, 'value': 0.90838274268021},
#  {'id': 9, 'time': 11, 'value': 44.87962877199031},
#  {'id': 54, 'time': 63, 'value': 65.38030906220503},
#  {'id': 19, 'time': 79, 'value': 91.86512991076152},
#  {'id': 146, 'time': 36, 'value': 17.27615542519581},
#  {'id': 25, 'time': 38, 'value': 17.14383100777706},
#  {'id': 47, 'time': 50, 'value': 39.93378528538831},
#  {'id': 105, 'time': 57, 'value': 59.38364531014624},
#  {'id': 20, 'time': 14, 'value': 8.066720843323298},
#  {'id': 22, 'time': 10, 'value': 46.43733398750632},
#  {'id': 110, 'time': 70, 'value': 57.63791169347814},
#  {'id': 71, 'time': 27, 'value': 0.2278603115447602},
#  {'id': 56, 'time': 99, 'value': 85.66217812621393},
#  {'id': 144, 'time': 16, 'value': 11.215655177153296},
#  {'id': 134, 'time': 27, 'value': 18.25493178405138}]

# %%
# make the time hints into a dataframe
predhints_df = pd.read_json(json.dumps(predHints),orient='records')
predhints_df
# Out:
#       id  time      value
# 0    122    43  17.544345
# 1      4    54  64.688271
# 2    132    11  43.428480
# 3    103    83  94.432832
# 4    110    44   8.429226
# ..   ...   ...        ...
# 419  110    70  57.637912
# 420   71    27   0.227860
# 421   56    99  85.662178
# 422  144    16  11.215655
# 423  134    27  18.254932
#
# [424 rows x 3 columns]

# %%
# lets plot the data we got from all the robots
alt.Chart(predhints_df).mark_point().encode(
    x='time:Q',
    y='mean(value):Q'
)
# Out:
# alt.Chart(...)

# %%
# we can tell the hacker we're interested in robots 99, 23 and 1
game.setRobotInterest([99,23,5])

# to reset to being interested in all, use
# game.setRobotInterest([])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # we can tell the hacker we're interested in robots 99, 23 and 1
# ----> 2 game.setRobotInterest([99,23,5])
#       4 # to reset to being interested in all, use
#       5 # game.setRobotInterest([])
#
# NameError: name 'game' is not defined

# %%
# we can also tell the hacker we're interesed in the 'Astrogation Buffer Length','InfoCore Size'
game.setPartInterest(['Astrogation Buffer Length','InfoCore Size'])

# to reset to being interested in all, use
# game.setPartInterest([])
# Out:
# {'Result': 'OK'}

# %%
# if we get more hints now, they'll be biased to the robots and parts we care about

for i in np.arange(0,3):
    # this will give us just the new hints, but the object will store everything we've seen
    hints = game.getHints()
    if ('parts' in hints):
        print('we got '+str(len(hints['parts']))+' part hints')
    time.sleep(6)
# Out:
# we got 12 part hints
# we got 12 part hints
# we got 12 part hints

# %%
# to set our bets, feed in a dictionary with the values
# for example, let's set robot id 0 to 99 and robot 5 to 72
game.setBets({0:99,5:72})
# Out:
# {'Result': 'OK'}

# %%
# let's see how we're doing, grab the data
robots = game.getRobotInfo()

# %%
# let's see how team 2 is doing (might be 0 if no deadlines expired)
robots[robots.winner == 2]['Productivity'].sum()
# Out:
# 333.012165982

# %%
# let's see how team 1 is doing (might be 0 if no deadlines expired or we didn't put in any bets)
robots[robots.winner == 1]['Productivity'].sum()
# Out:
# 0.0

# %%
# Here's a hint on how you can use the data you get to predict the value.
# Let's say we learn two points about a robot's random number generator
# At time 17, they'll say 40 and at time 50, they'll say 27
xs = [17,50]
ys = [40,27]

# %%
# we can use this to generate simple regression. One way to do it is to just fit a one dimensional polynomial
fit = np.polyfit(xs,ys,1)

# in reality, 1 dimension is probably not ideal

# %%
# next, we'll want to figure out all the y values over the range of times 0 to 100
fitx = np.arange(0,100)
fity = []

# %%
# create the fit function using the fit we calculated above
fitfunc = np.poly1d(fit)
for x in fitx:
    y = fitfunc(x)
    if (y > 100): # we know y can't be > 100
        y = 100
    if (y < 0): # we know y can't be < 0
        y = 0
    fity.append(y)

# %%
# to visualize this, I'm going to build a dataset the has both the original numbers 
# our hacker gave us (17,50 and 40,27) and the new things we calculated:
vals = []
for i in np.arange(0,len(xs)):
    vals.append({'t':'hint','x':int(xs[i]),'y':int(ys[i])})
   
for i in np.arange(0,len(fitx)):
    vals.append({'t':'fit','x':int(fitx[i]),'y':int(fity[i])})

# so now we have a dataset with both the hint and fit data
# you can look at it here
# vals

# %%
# finally, let's plot the data using Altair

# first make a chart for the hints
hintlayer = alt.Chart(alt.Data(values=vals)).mark_circle(filled=True,size=90,color='red').encode(
    x='x:Q',
    y='y:Q',
    color='t:N'
).transform_filter(
    alt.datum.t == 'hint'
)

# overlay that with the predictions
fitlayer = alt.Chart(alt.Data(values=vals)).mark_line().encode(
    x='x:Q',
    y='y:Q',
    color='t:N'
).transform_filter(
    alt.datum.t == 'fit'
)

# and let's assume an expiration of 70 for this robot and draw a line on top

annotationlayer = alt.Chart(pd.DataFrame({'x': [70]})).mark_rule().encode(x='x:Q')

# layer the charts
hintlayer + fitlayer + annotationlayer
# Out:
# /Users/eadar/anaconda3/envs/robogames3/lib/python3.9/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.LayerChart(...)

# %% [markdown]
# ## A few other random "recipes"

# %%
# set all the bets to 80
bets = {}
for i in np.arange(0,100):
    bets[int(i)] = int(80)
game.setBets(bets)
# Out:
# {'Result': 'OK'}

# %%
# get all the game parts since the start of the game
game.getHints(hintstart=0)['parts']
# Out:
# [{'column': 'Astrogation Buffer Length', 'id': 3, 'value': 1.353986449},
#  {'column': 'Nanochip Model', 'id': 95, 'value': 'model C'},
#  {'column': 'Polarity Sinks', 'id': 84, 'value': 0.540174034},
#  {'column': 'Cranial Uplink Bandwidth', 'id': 26, 'value': 69.0},
#  {'column': 'Arakyd Vocabulator Model', 'id': 83, 'value': 'gamma'},
#  {'column': 'Cranial Uplink Bandwidth', 'id': 49, 'value': 28.0},
#  {'column': 'Polarity Sinks', 'id': 74, 'value': 0.717702572},
#  {'column': 'Cranial Uplink Bandwidth', 'id': 5, 'value': 24.0},
#  {'column': 'AutoTerrain Tread Count', 'id': 82, 'value': 5.0},
#  {'column': 'Sonoreceptors', 'id': 49, 'value': -1.064011965},
#  {'column': 'Nanochip Model', 'id': 90, 'value': 'model E'},
#  {'column': 'Polarity Sinks', 'id': 28, 'value': 0.851447344},
#  {'column': 'InfoCore Size', 'id': 66, 'value': -0.574233703},
#  {'column': 'Axial Piston Model', 'id': 32, 'value': 'windows 2000'},
#  {'column': 'InfoCore Size', 'id': 85, 'value': -0.275895803},
#  {'column': 'Polarity Sinks', 'id': 75, 'value': 0.434331725},
#  {'column': 'Polarity Sinks', 'id': 4, 'value': 1.062709657},
#  {'column': 'Repulsorlift Motor HP', 'id': 11, 'value': 1.388339697},
#  {'column': 'AutoTerrain Tread Count', 'id': 15, 'value': 94.0},
#  {'column': 'Astrogation Buffer Length', 'id': 74, 'value': 1.467841442},
#  {'column': 'Arakyd Vocabulator Model', 'id': 75, 'value': 'kappa'},
#  {'column': 'Astrogation Buffer Length', 'id': 79, 'value': 1.720898661},
#  {'column': 'Sonoreceptors', 'id': 62, 'value': -0.651743068},
#  {'column': 'Nanochip Model', 'id': 55, 'value': 'model C'},
#  {'column': 'Cranial Uplink Bandwidth', 'id': 23, 'value': 23.0},
#  {'column': 'Axial Piston Model', 'id': 37, 'value': 'v1.5'},
#  {'column': 'InfoCore Size', 'id': 65, 'value': -0.247817679},
#  {'column': 'Astrogation Buffer Length', 'id': 98, 'value': 1.514847626},
#  {'column': 'Axial Piston Model', 'id': 19, 'value': 'v0.5'},
#  {'column': 'Cranial Uplink Bandwidth', 'id': 96, 'value': 88.0},
#  {'column': 'Astrogation Buffer Length', 'id': 42, 'value': 1.258373939},
#  {'column': 'Cranial Uplink Bandwidth', 'id': 95, 'value': 50.0},
#  {'column': 'Sonoreceptors', 'id': 47, 'value': -0.576014697},
#  {'column': 'Polarity Sinks', 'id': 5, 'value': 0.649830144},
#  {'column': 'Polarity Sinks', 'id': 40, 'value': 0.732526228},
#  {'column': 'Arakyd Vocabulator Model', 'id': 73, 'value': 'kappa'},
#  {'column': 'InfoCore Size', 'id': 21, 'value': -0.295490404},
#  {'column': 'Polarity Sinks', 'id': 64, 'value': 0.989397905},
#  {'column': 'Astrogation Buffer Length', 'id': 51, 'value': 1.439077797},
#  {'column': 'Astrogation Buffer Length', 'id': 62, 'value': 1.31903767},
#  {'column': 'InfoCore Size', 'id': 71, 'value': -0.254699485},
#  {'column': 'Astrogation Buffer Length', 'id': 14, 'value': 1.11862404},
#  {'column': 'Cranial Uplink Bandwidth', 'id': 26, 'value': 69.0},
#  {'column': 'Repulsorlift Motor HP', 'id': 37, 'value': 1.611095125},
#  {'column': 'Sonoreceptors', 'id': 7, 'value': -0.835758878},
#  {'column': 'Astrogation Buffer Length', 'id': 65, 'value': 1.527880001},
#  {'column': 'InfoCore Size', 'id': 91, 'value': -0.340829988},
#  {'column': 'InfoCore Size', 'id': 99, 'value': -0.638532961},
#  {'column': 'Sonoreceptors', 'id': 78, 'value': -1.036967162},
#  {'column': 'Arakyd Vocabulator Model', 'id': 0, 'value': 'gamma'},
#  {'column': 'AutoTerrain Tread Count', 'id': 87, 'value': 82.0},
#  {'column': 'InfoCore Size', 'id': 56, 'value': -0.21454931},
#  {'column': 'Astrogation Buffer Length', 'id': 38, 'value': 1.251952383},
#  {'column': 'Astrogation Buffer Length', 'id': 69, 'value': 0.933022966},
#  {'column': 'Astrogation Buffer Length', 'id': 71, 'value': 1.282881311},
#  {'column': 'InfoCore Size', 'id': 89, 'value': -0.287281221},
#  {'column': 'Sonoreceptors', 'id': 30, 'value': -0.380709139},
#  {'column': 'InfoCore Size', 'id': 91, 'value': -0.340829988},
#  {'column': 'Astrogation Buffer Length', 'id': 78, 'value': 1.512213273},
#  {'column': 'InfoCore Size', 'id': 97, 'value': -0.732268473}]

# %%
# debug information while game is in simulation
game.getDebug()
# Out:
# {'team1secret': 'bob',
#  'team2secret': '8d537ac6-a631-4c8e-872f-7542ffbccc87',
#  'team1_int_bots': [[],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [99, 23, 5],
#   [99, 23, 5],
#   [99, 23, 5],
#   [99, 23, 5],
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'team2_int_bots': [[],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'team1_int_parts': [[],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   ['Astrogation Buffer Length', 'InfoCore Size'],
#   ['Astrogation Buffer Length', 'InfoCore Size'],
#   ['Astrogation Buffer Length', 'InfoCore Size'],
#   ['Astrogation Buffer Length', 'InfoCore Size'],
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'team2_int_parts': [[],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'team1_hints_bots': [[],
#   [{'id': 118, 'time': 50, 'value': 81.59939575},
#    {'id': 119, 'time': 48, 'value': 6.121980766},
#    {'id': 125, 'time': 22, 'value': 76.42862206},
#    {'id': 137, 'time': 1, 'value': 43.37216434},
#    {'id': 79, 'time': 83, 'value': 98.34869226},
#    {'id': 61, 'time': 22, 'value': 55.60030533},
#    {'id': 11, 'time': 49, 'value': 15.08104208},
#    {'id': 117, 'time': 70, 'value': 92.61311604},
#    {'id': 76, 'time': 49, 'value': 12.44997407},
#    {'id': 109, 'time': 24, 'value': 98.41068479}],
#   [{'id': 140, 'time': 9, 'value': 37.18247848},
#    {'id': 114, 'time': 86, 'value': 90.10023602},
#    {'id': 104, 'time': 97, 'value': 75.34332443},
#    {'id': 4, 'time': 76, 'value': 92.98526201},
#    {'id': 106, 'time': 5, 'value': 11.44563706},
#    {'id': 19, 'time': 65, 'value': 84.303551},
#    {'id': 57, 'time': 79, 'value': 100.0},
#    {'id': 74, 'time': 14, 'value': 24.35829729},
#    {'id': 148, 'time': 68, 'value': 88.52425556},
#    {'id': 141, 'time': 8, 'value': 11.20916827}],
#   [{'id': 53, 'time': 89, 'value': 99.01739449},
#    {'id': 35, 'time': 26, 'value': 21.95795421},
#    {'id': 118, 'time': 38, 'value': 78.13219887},
#    {'id': 117, 'time': 66, 'value': 86.23701155},
#    {'id': 102, 'time': 28, 'value': 18.76182512}],
#   [{'id': 89, 'time': 34, 'value': 27.61344284},
#    {'id': 91, 'time': 83, 'value': 97.29914812},
#    {'id': 131, 'time': 100, 'value': 50.24630185},
#    {'id': 57, 'time': 63, 'value': 82.22955295},
#    {'id': 37, 'time': 30, 'value': 7.799148889},
#    {'id': 114, 'time': 45, 'value': 59.45610731},
#    {'id': 112, 'time': 87, 'value': 97.86922976},
#    {'id': 80, 'time': 69, 'value': 99.48144798},
#    {'id': 116, 'time': 97, 'value': 59.55504534},
#    {'id': 74, 'time': 83, 'value': 98.95585143}],
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'team1_hints_parts': [[],
#   [{'id': 3, 'column': 'Astrogation Buffer Length', 'value': 1.353986449},
#    {'id': 95, 'column': 'Nanochip Model', 'value': 'model C'},
#    {'id': 84, 'column': 'Polarity Sinks', 'value': 0.540174034},
#    {'id': 26, 'column': 'Cranial Uplink Bandwidth', 'value': 69.0},
#    {'id': 83, 'column': 'Arakyd Vocabulator Model', 'value': 'gamma'},
#    {'id': 49, 'column': 'Cranial Uplink Bandwidth', 'value': 28.0}],
#   [{'id': 74, 'column': 'Polarity Sinks', 'value': 0.717702572},
#    {'id': 5, 'column': 'Cranial Uplink Bandwidth', 'value': 24.0},
#    {'id': 82, 'column': 'AutoTerrain Tread Count', 'value': 5.0},
#    {'id': 49, 'column': 'Sonoreceptors', 'value': -1.064011965},
#    {'id': 90, 'column': 'Nanochip Model', 'value': 'model E'},
#    {'id': 28, 'column': 'Polarity Sinks', 'value': 0.851447344}],
#   [{'id': 66, 'column': 'InfoCore Size', 'value': -0.574233703},
#    {'id': 32, 'column': 'Axial Piston Model', 'value': 'windows 2000'},
#    {'id': 85, 'column': 'InfoCore Size', 'value': -0.275895803},
#    {'id': 75, 'column': 'Polarity Sinks', 'value': 0.434331725},
#    {'id': 4, 'column': 'Polarity Sinks', 'value': 1.062709657},
#    {'id': 11, 'column': 'Repulsorlift Motor HP', 'value': 1.388339697}],
#   [{'id': 15, 'column': 'AutoTerrain Tread Count', 'value': 94.0},
#    {'id': 74, 'column': 'Astrogation Buffer Length', 'value': 1.467841442},
#    {'id': 75, 'column': 'Arakyd Vocabulator Model', 'value': 'kappa'},
#    {'id': 79, 'column': 'Astrogation Buffer Length', 'value': 1.720898661},
#    {'id': 62, 'column': 'Sonoreceptors', 'value': -0.651743068},
#    {'id': 55, 'column': 'Nanochip Model', 'value': 'model C'}],
#   [{'id': 23, 'column': 'Cranial Uplink Bandwidth', 'value': 23.0},
#    {'id': 37, 'column': 'Axial Piston Model', 'value': 'v1.5'},
#    {'id': 65, 'column': 'InfoCore Size', 'value': -0.247817679},
#    {'id': 98, 'column': 'Astrogation Buffer Length', 'value': 1.514847626},
#    {'id': 19, 'column': 'Axial Piston Model', 'value': 'v0.5'},
#    {'id': 96, 'column': 'Cranial Uplink Bandwidth', 'value': 88.0}],
#   [{'id': 42, 'column': 'Astrogation Buffer Length', 'value': 1.258373939},
#    {'id': 95, 'column': 'Cranial Uplink Bandwidth', 'value': 50.0},
#    {'id': 47, 'column': 'Sonoreceptors', 'value': -0.576014697},
#    {'id': 5, 'column': 'Polarity Sinks', 'value': 0.649830144},
#    {'id': 40, 'column': 'Polarity Sinks', 'value': 0.732526228},
#    {'id': 73, 'column': 'Arakyd Vocabulator Model', 'value': 'kappa'}],
#   [{'id': 21, 'column': 'InfoCore Size', 'value': -0.295490404},
#    {'id': 64, 'column': 'Polarity Sinks', 'value': 0.989397905},
#    {'id': 51, 'column': 'Astrogation Buffer Length', 'value': 1.439077797},
#    {'id': 62, 'column': 'Astrogation Buffer Length', 'value': 1.31903767},
#    {'id': 71, 'column': 'InfoCore Size', 'value': -0.254699485},
#    {'id': 14, 'column': 'Astrogation Buffer Length', 'value': 1.11862404}],
#   [{'id': 26, 'column': 'Cranial Uplink Bandwidth', 'value': 69.0},
#    {'id': 37, 'column': 'Repulsorlift Motor HP', 'value': 1.611095125},
#    {'id': 7, 'column': 'Sonoreceptors', 'value': -0.835758878},
#    {'id': 65, 'column': 'Astrogation Buffer Length', 'value': 1.527880001},
#    {'id': 91, 'column': 'InfoCore Size', 'value': -0.340829988},
#    {'id': 99, 'column': 'InfoCore Size', 'value': -0.638532961}],
#   [{'id': 78, 'column': 'Sonoreceptors', 'value': -1.036967162},
#    {'id': 0, 'column': 'Arakyd Vocabulator Model', 'value': 'gamma'},
#    {'id': 87, 'column': 'AutoTerrain Tread Count', 'value': 82.0},
#    {'id': 56, 'column': 'InfoCore Size', 'value': -0.21454931},
#    {'id': 38, 'column': 'Astrogation Buffer Length', 'value': 1.251952383},
#    {'id': 69, 'column': 'Astrogation Buffer Length', 'value': 0.933022966}],
#   [{'id': 71, 'column': 'Astrogation Buffer Length', 'value': 1.282881311},
#    {'id': 89, 'column': 'InfoCore Size', 'value': -0.287281221},
#    {'id': 30, 'column': 'Sonoreceptors', 'value': -0.380709139},
#    {'id': 91, 'column': 'InfoCore Size', 'value': -0.340829988},
#    {'id': 78, 'column': 'Astrogation Buffer Length', 'value': 1.512213273},
#    {'id': 97, 'column': 'InfoCore Size', 'value': -0.732268473}],
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'team2_hints_parts': [[],
#   [{'id': 36, 'column': 'Arakyd Vocabulator Model', 'value': 'kappa'},
#    {'id': 3, 'column': 'AutoTerrain Tread Count', 'value': 25.0},
#    {'id': 30, 'column': 'Repulsorlift Motor HP', 'value': 0.974843035},
#    {'id': 95, 'column': 'InfoCore Size', 'value': 0.006344025},
#    {'id': 21, 'column': 'AutoTerrain Tread Count', 'value': 3.0},
#    {'id': 22, 'column': 'Arakyd Vocabulator Model', 'value': 'gamma'}],
#   [{'id': 21, 'column': 'Nanochip Model', 'value': 'model C'},
#    {'id': 17, 'column': 'Sonoreceptors', 'value': -0.240758012},
#    {'id': 78, 'column': 'Sonoreceptors', 'value': -1.036967162},
#    {'id': 58, 'column': 'Astrogation Buffer Length', 'value': 0.90454043},
#    {'id': 24, 'column': 'AutoTerrain Tread Count', 'value': 55.0},
#    {'id': 5, 'column': 'Cranial Uplink Bandwidth', 'value': 24.0}],
#   [{'id': 78, 'column': 'Repulsorlift Motor HP', 'value': 1.624597867},
#    {'id': 38, 'column': 'Arakyd Vocabulator Model', 'value': 'kappa'},
#    {'id': 34, 'column': 'Axial Piston Model', 'value': 'v1.0'},
#    {'id': 85, 'column': 'Arakyd Vocabulator Model', 'value': 'kappa'},
#    {'id': 44, 'column': 'AutoTerrain Tread Count', 'value': 50.0},
#    {'id': 24, 'column': 'Arakyd Vocabulator Model', 'value': 'kappa'}],
#   [{'id': 88, 'column': 'Cranial Uplink Bandwidth', 'value': 62.0},
#    {'id': 44, 'column': 'Nanochip Model', 'value': 'model D'},
#    {'id': 70, 'column': 'Arakyd Vocabulator Model', 'value': 'kappa'},
#    {'id': 24, 'column': 'Sonoreceptors', 'value': -0.716615674},
#    {'id': 0, 'column': 'InfoCore Size', 'value': -0.446873531},
#    {'id': 40, 'column': 'Sonoreceptors', 'value': -0.758682361}],
#   [{'id': 52, 'column': 'Astrogation Buffer Length', 'value': 1.364388751},
#    {'id': 13, 'column': 'Astrogation Buffer Length', 'value': 0.808342007},
#    {'id': 24, 'column': 'Nanochip Model', 'value': 'model E'},
#    {'id': 62, 'column': 'InfoCore Size', 'value': -0.335127704},
#    {'id': 11, 'column': 'AutoTerrain Tread Count', 'value': 22.0},
#    {'id': 56, 'column': 'Axial Piston Model', 'value': 'windows 2000'}],
#   [{'id': 70, 'column': 'InfoCore Size', 'value': -0.585906587},
#    {'id': 89, 'column': 'Sonoreceptors', 'value': -0.72437201},
#    {'id': 13, 'column': 'Astrogation Buffer Length', 'value': 0.808342007},
#    {'id': 5, 'column': 'Sonoreceptors', 'value': -0.638719452},
#    {'id': 61, 'column': 'Axial Piston Model', 'value': 'v1.5'},
#    {'id': 75, 'column': 'Axial Piston Model', 'value': 'windows 2000'}],
#   [{'id': 5, 'column': 'InfoCore Size', 'value': -0.547317146},
#    {'id': 30, 'column': 'AutoTerrain Tread Count', 'value': 97.0},
#    {'id': 59, 'column': 'Repulsorlift Motor HP', 'value': 1.230031167},
#    {'id': 64, 'column': 'Polarity Sinks', 'value': 0.989397905},
#    {'id': 92, 'column': 'Repulsorlift Motor HP', 'value': 1.450959146},
#    {'id': 76, 'column': 'Nanochip Model', 'value': 'model E'}],
#   [{'id': 8, 'column': 'InfoCore Size', 'value': -0.175313588},
#    {'id': 17, 'column': 'Cranial Uplink Bandwidth', 'value': 16.0},
#    {'id': 68, 'column': 'Repulsorlift Motor HP', 'value': 1.307562635},
#    {'id': 97, 'column': 'Cranial Uplink Bandwidth', 'value': 44.0},
#    {'id': 53, 'column': 'Repulsorlift Motor HP', 'value': 0.877782737},
#    {'id': 59, 'column': 'Axial Piston Model', 'value': 'v1.0'}],
#   [{'id': 95, 'column': 'Astrogation Buffer Length', 'value': 1.080996708},
#    {'id': 18, 'column': 'Astrogation Buffer Length', 'value': 0.963953401},
#    {'id': 48, 'column': 'InfoCore Size', 'value': -0.526234898},
#    {'id': 23, 'column': 'InfoCore Size', 'value': -0.750507888},
#    {'id': 83, 'column': 'Axial Piston Model', 'value': 'v1.5'},
#    {'id': 27, 'column': 'Cranial Uplink Bandwidth', 'value': 95.0}],
#   [{'id': 39, 'column': 'Nanochip Model', 'value': 'model E'},
#    {'id': 59, 'column': 'Axial Piston Model', 'value': 'v1.0'},
#    {'id': 52, 'column': 'Polarity Sinks', 'value': 0.824209987},
#    {'id': 2, 'column': 'Cranial Uplink Bandwidth', 'value': 24.0},
#    {'id': 67, 'column': 'Polarity Sinks', 'value': 0.456844895},
#    {'id': 78, 'column': 'InfoCore Size', 'value': -0.365738506}],
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'starttime': -1,
#  'team1_ready': 1,
#  'team2_ready': 1,
#  'team1_bets': [80,
#   80,
#   80,
#   -1,
#   80,
#   -1,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   -1,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   -1,
#   -1,
#   -1,
#   80,
#   80,
#   80,
#   -1,
#   -1,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   -1,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   -1,
#   80,
#   80,
#   -1,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   -1,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   -1,
#   -1,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80,
#   80],
#  'team2_bets': [50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50],
#  'betlog': [{'time': 0, 'betby': 2, 'beton': 0, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 1, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 2, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 3, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 4, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 5, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 6, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 7, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 8, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 9, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 10, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 11, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 12, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 13, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 14, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 15, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 16, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 17, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 18, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 19, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 20, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 21, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 22, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 23, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 24, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 25, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 26, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 27, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 28, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 29, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 30, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 31, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 32, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 33, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 34, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 35, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 36, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 37, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 38, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 39, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 40, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 41, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 42, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 43, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 44, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 45, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 46, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 47, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 48, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 49, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 50, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 51, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 52, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 53, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 54, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 55, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 56, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 57, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 58, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 59, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 60, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 61, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 62, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 63, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 64, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 65, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 66, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 67, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 68, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 69, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 70, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 71, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 72, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 73, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 74, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 75, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 76, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 77, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 78, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 79, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 80, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 81, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 82, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 83, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 84, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 85, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 86, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 87, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 88, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 89, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 90, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 91, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 92, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 93, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 94, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 95, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 96, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 97, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 98, 'value': 50},
#   {'time': 0, 'betby': 2, 'beton': 99, 'value': 50},
#   {'time': 9.8, 'betby': 1, 'beton': 0, 'value': 99},
#   {'time': 9.85, 'betby': 1, 'beton': 0, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 1, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 2, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 4, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 6, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 7, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 8, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 9, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 10, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 11, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 12, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 13, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 14, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 15, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 17, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 18, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 19, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 20, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 21, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 22, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 23, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 24, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 25, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 26, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 27, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 28, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 29, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 30, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 31, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 35, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 36, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 37, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 40, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 41, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 42, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 43, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 44, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 45, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 46, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 47, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 49, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 50, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 51, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 52, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 53, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 54, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 55, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 56, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 57, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 58, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 59, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 60, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 61, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 62, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 63, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 64, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 66, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 67, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 69, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 70, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 71, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 72, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 73, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 74, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 75, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 76, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 78, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 79, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 80, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 81, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 82, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 83, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 84, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 85, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 86, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 87, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 88, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 89, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 92, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 93, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 94, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 95, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 96, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 97, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 98, 'value': 80},
#   {'time': 9.85, 'betby': 1, 'beton': 99, 'value': 80}],
#  'winreasons': [{'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': 2, 'reason': -1},
#   {'winner': -2, 'reason': -2},
#   {'winner': 2, 'reason': -1},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': 2, 'reason': -1},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': 2, 'reason': -1},
#   {'winner': 2, 'reason': -1},
#   {'winner': 2, 'reason': -1},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': 2, 'reason': -1},
#   {'winner': 2, 'reason': -1},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': 2, 'reason': -1},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': 2, 'reason': -1},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': 2, 'reason': -1},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': 2, 'reason': -1},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': 2, 'reason': -1},
#   {'winner': 2, 'reason': -1},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2},
#   {'winner': -2, 'reason': -2}],
#  'team1_lasthint': 10,
#  'team2_lasthint': 0,
#  'debug': True,
#  'gameid': 'examplematch1',
#  'matchfile': '492e2b81-4ecc-49a5-a079-67ec24a69ad4.examplematch1.json',
#  'socialnet': {'directed': False,
#   'multigraph': False,
#   'graph': {},
#   'nodes': [{'id': [0, 0]},
#    {'id': [0, 1]},
#    {'id': [0, 2]},
#    {'id': [0, 3]},
#    {'id': [0, 4]},
#    {'id': [0, 5]},
#    {'id': [0, 6]},
#    {'id': [0, 7]},
#    {'id': [0, 8]},
#    {'id': [0, 9]},
#    {'id': [1, 0]},
#    {'id': [1, 1]},
#    {'id': [1, 2]},
#    {'id': [1, 3]},
#    {'id': [1, 4]},
#    {'id': [1, 5]},
#    {'id': [1, 6]},
#    {'id': [1, 7]},
#    {'id': [1, 8]},
#    {'id': [1, 9]},
#    {'id': [2, 0]},
#    {'id': [2, 1]},
#    {'id': [2, 2]},
#    {'id': [2, 3]},
#    {'id': [2, 4]},
#    {'id': [2, 5]},
#    {'id': [2, 6]},
#    {'id': [2, 7]},
#    {'id': [2, 8]},
#    {'id': [2, 9]},
#    {'id': [3, 0]},
#    {'id': [3, 1]},
#    {'id': [3, 2]},
#    {'id': [3, 3]},
#    {'id': [3, 4]},
#    {'id': [3, 5]},
#    {'id': [3, 6]},
#    {'id': [3, 7]},
#    {'id': [3, 8]},
#    {'id': [3, 9]},
#    {'id': [4, 0]},
#    {'id': [4, 1]},
#    {'id': [4, 2]},
#    {'id': [4, 3]},
#    {'id': [4, 4]},
#    {'id': [4, 5]},
#    {'id': [4, 6]},
#    {'id': [4, 7]},
#    {'id': [4, 8]},
#    {'id': [4, 9]},
#    {'id': [5, 0]},
#    {'id': [5, 1]},
#    {'id': [5, 2]},
#    {'id': [5, 3]},
#    {'id': [5, 4]},
#    {'id': [5, 5]},
#    {'id': [5, 6]},
#    {'id': [5, 7]},
#    {'id': [5, 8]},
#    {'id': [5, 9]},
#    {'id': [6, 0]},
#    {'id': [6, 1]},
#    {'id': [6, 2]},
#    {'id': [6, 3]},
#    {'id': [6, 4]},
#    {'id': [6, 5]},
#    {'id': [6, 6]},
#    {'id': [6, 7]},
#    {'id': [6, 8]},
#    {'id': [6, 9]},
#    {'id': [7, 0]},
#    {'id': [7, 1]},
#    {'id': [7, 2]},
#    {'id': [7, 3]},
#    {'id': [7, 4]},
#    {'id': [7, 5]},
#    {'id': [7, 6]},
#    {'id': [7, 7]},
#    {'id': [7, 8]},
#    {'id': [7, 9]},
#    {'id': [8, 0]},
#    {'id': [8, 1]},
#    {'id': [8, 2]},
#    {'id': [8, 3]},
#    {'id': [8, 4]},
#    {'id': [8, 5]},
#    {'id': [8, 6]},
#    {'id': [8, 7]},
#    {'id': [8, 8]},
#    {'id': [8, 9]},
#    {'id': [9, 0]},
#    {'id': [9, 1]},
#    {'id': [9, 2]},
#    {'id': [9, 3]},
#    {'id': [9, 4]},
#    {'id': [9, 5]},
#    {'id': [9, 6]},
#    {'id': [9, 7]},
#    {'id': [9, 8]},
#    {'id': [9, 9]}],
#   'links': [{'source': [0, 0], 'target': [1, 0]},
#    {'source': [0, 0], 'target': [0, 1]},
#    {'source': [0, 1], 'target': [1, 1]},
#    {'source': [0, 1], 'target': [0, 2]},
#    {'source': [0, 2], 'target': [1, 2]},
#    {'source': [0, 2], 'target': [0, 3]},
#    {'source': [0, 3], 'target': [1, 3]},
#    {'source': [0, 3], 'target': [0, 4]},
#    {'source': [0, 4], 'target': [1, 4]},
#    {'source': [0, 4], 'target': [0, 5]},
#    {'source': [0, 5], 'target': [1, 5]},
#    {'source': [0, 5], 'target': [0, 6]},
#    {'source': [0, 6], 'target': [1, 6]},
#    {'source': [0, 6], 'target': [0, 7]},
#    {'source': [0, 7], 'target': [1, 7]},
#    {'source': [0, 7], 'target': [0, 8]},
#    {'source': [0, 8], 'target': [1, 8]},
#    {'source': [0, 8], 'target': [0, 9]},
#    {'source': [0, 9], 'target': [1, 9]},
#    {'source': [1, 0], 'target': [2, 0]},
#    {'source': [1, 0], 'target': [1, 1]},
#    {'source': [1, 1], 'target': [2, 1]},
#    {'source': [1, 1], 'target': [1, 2]},
#    {'source': [1, 2], 'target': [2, 2]},
#    {'source': [1, 2], 'target': [1, 3]},
#    {'source': [1, 3], 'target': [2, 3]},
#    {'source': [1, 3], 'target': [1, 4]},
#    {'source': [1, 4], 'target': [2, 4]},
#    {'source': [1, 4], 'target': [1, 5]},
#    {'source': [1, 5], 'target': [2, 5]},
#    {'source': [1, 5], 'target': [1, 6]},
#    {'source': [1, 6], 'target': [2, 6]},
#    {'source': [1, 6], 'target': [1, 7]},
#    {'source': [1, 7], 'target': [2, 7]},
#    {'source': [1, 7], 'target': [1, 8]},
#    {'source': [1, 8], 'target': [2, 8]},
#    {'source': [1, 8], 'target': [1, 9]},
#    {'source': [1, 9], 'target': [2, 9]},
#    {'source': [2, 0], 'target': [3, 0]},
#    {'source': [2, 0], 'target': [2, 1]},
#    {'source': [2, 1], 'target': [3, 1]},
#    {'source': [2, 1], 'target': [2, 2]},
#    {'source': [2, 2], 'target': [3, 2]},
#    {'source': [2, 2], 'target': [2, 3]},
#    {'source': [2, 3], 'target': [3, 3]},
#    {'source': [2, 3], 'target': [2, 4]},
#    {'source': [2, 4], 'target': [3, 4]},
#    {'source': [2, 4], 'target': [2, 5]},
#    {'source': [2, 5], 'target': [3, 5]},
#    {'source': [2, 5], 'target': [2, 6]},
#    {'source': [2, 6], 'target': [3, 6]},
#    {'source': [2, 6], 'target': [2, 7]},
#    {'source': [2, 7], 'target': [3, 7]},
#    {'source': [2, 7], 'target': [2, 8]},
#    {'source': [2, 8], 'target': [3, 8]},
#    {'source': [2, 8], 'target': [2, 9]},
#    {'source': [2, 9], 'target': [3, 9]},
#    {'source': [3, 0], 'target': [4, 0]},
#    {'source': [3, 0], 'target': [3, 1]},
#    {'source': [3, 1], 'target': [4, 1]},
#    {'source': [6, 5], 'target': [6, 6]},
#    {'source': [6, 6], 'target': [7, 6]},
#    {'source': [6, 6], 'target': [6, 7]},
#    {'source': [6, 7], 'target': [7, 7]},
#    {'source': [6, 7], 'target': [6, 8]},
#    {'source': [6, 8], 'target': [7, 8]},
#    {'source': [6, 8], 'target': [6, 9]},
#    {'source': [6, 9], 'target': [7, 9]},
#    {'source': [7, 0], 'target': [8, 0]},
#    {'source': [7, 0], 'target': [7, 1]},
#    {'source': [7, 1], 'target': [8, 1]},
#    {'source': [7, 1], 'target': [7, 2]},
#    {'source': [7, 2], 'target': [8, 2]},
#    {'source': [7, 2], 'target': [7, 3]},
#    {'source': [7, 3], 'target': [8, 3]},
#    {'source': [7, 3], 'target': [7, 4]},
#    {'source': [7, 4], 'target': [8, 4]},
#    {'source': [7, 4], 'target': [7, 5]},
#    {'source': [7, 5], 'target': [8, 5]},
#    {'source': [7, 5], 'target': [7, 6]},
#    {'source': [7, 6], 'target': [8, 6]},
#    {'source': [7, 6], 'target': [7, 7]},
#    {'source': [7, 7], 'target': [8, 7]},
#    {'source': [7, 7], 'target': [7, 8]},
#    {'source': [7, 8], 'target': [8, 8]},
#    {'source': [7, 8], 'target': [7, 9]},
#    {'source': [7, 9], 'target': [8, 9]},
#    {'source': [8, 0], 'target': [9, 0]},
#    {'source': [8, 0], 'target': [8, 1]},
#    {'source': [8, 1], 'target': [9, 1]},
#    {'source': [8, 1], 'target': [8, 2]},
#    {'source': [8, 2], 'target': [9, 2]},
#    {'source': [8, 2], 'target': [8, 3]},
#    {'source': [8, 3], 'target': [9, 3]},
#    {'source': [8, 3], 'target': [8, 4]},
#    {'source': [8, 4], 'target': [9, 4]},
#    {'source': [8, 4], 'target': [8, 5]},
#    {'source': [8, 5], 'target': [9, 5]},
#    {'source': [8, 5], 'target': [8, 6]},
#    {'source': [8, 6], 'target': [9, 6]},
#    {'source': [8, 6], 'target': [8, 7]},
#    {'source': [8, 7], 'target': [9, 7]},
#    {'source': [8, 7], 'target': [8, 8]},
#    {'source': [8, 8], 'target': [9, 8]},
#    {'source': [8, 8], 'target': [8, 9]},
#    {'source': [8, 9], 'target': [9, 9]},
#    {'source': [9, 0], 'target': [9, 1]},
#    {'source': [9, 1], 'target': [9, 2]},
#    {'source': [9, 2], 'target': [9, 3]},
#    {'source': [9, 3], 'target': [9, 4]},
#    {'source': [9, 4], 'target': [9, 5]},
#    {'source': [9, 5], 'target': [9, 6]},
#    {'source': [9, 6], 'target': [9, 7]},
#    {'source': [9, 7], 'target': [9, 8]},
#    {'source': [9, 8], 'target': [9, 9]}]},
#  'genealogy': {'id': 152,
#   'children': [{'id': 149,
#     'children': [{'id': 131,
#       'children': [{'id': 104,
#         'children': [{'id': 17}, {'id': 51}, {'id': 46}, {'id': 16}]},
#        {'id': 74},
#        {'id': 43}]},
#      {'id': 143,
#       'children': [{'id': 101, 'children': [{'id': 63}, {'id': 73}]},
#        {'id': 117,
#         'children': [{'id': 106,
#           'children': [{'id': 70}, {'id': 80}, {'id': 71}]},
#          {'id': 91}]},
#        {'id': 141,
#         'children': [{'id': 123,
#           'children': [{'id': 75}, {'id': 89}, {'id': 83}]},
#          {'id': 53}]},
#        {'id': 1}]},
#      {'id': 147,
#       'children': [{'id': 145,
#         'children': [{'id': 138,
#           'children': [{'id': 103, 'children': [{'id': 41}, {'id': 84}]},
#            {'id': 127,
#             'children': [{'id': 105, 'children': [{'id': 67}, {'id': 48}]},
#              {'id': 95}]},
#            {'id': 94}]},
#          {'id': 142,
#           'children': [{'id': 124,
#             'children': [{'id': 100, 'children': [{'id': 49}, {'id': 8}]},
#              {'id': 120,
#               'children': [{'id': 115,
#                 'children': [{'id': 111, 'children': [{'id': 78}, {'id': 12}]},
#                  {'id': 52}]},
#                {'id': 119,
#                 'children': [{'id': 108, 'children': [{'id': 82}, {'id': 2}]},
#                  {'id': 110,
#                   'children': [{'id': 9}, {'id': 7}, {'id': 11}, {'id': 20}]},
#                  {'id': 23}]},
#                {'id': 47},
#                {'id': 33}]},
#              {'id': 97},
#              {'id': 58}]},
#            {'id': 4}]}]},
#        {'id': 146,
#         'children': [{'id': 130,
#           'children': [{'id': 107,
#             'children': [{'id': 102,
#               'children': [{'id': 65}, {'id': 64}, {'id': 76}]},
#              {'id': 38},
#              {'id': 21},
#              {'id': 37}]},
#            {'id': 10}]},
#          {'id': 139,
#           'children': [{'id': 136,
#             'children': [{'id': 112,
#               'children': [{'id': 72}, {'id': 79}, {'id': 14}, {'id': 6}]},
#              {'id': 133,
#               'children': [{'id': 114,
#                 'children': [{'id': 86}, {'id': 3}, {'id': 25}, {'id': 22}]},
#                {'id': 0},
#                {'id': 24}]},
#              {'id': 61}]},
#            {'id': 59},
#            {'id': 90}]}]},
#        {'id': 62}]}]},
#    {'id': 150,
#     'children': [{'id': 140,
#       'children': [{'id': 116,
#         'children': [{'id': 113,
#           'children': [{'id': 81}, {'id': 99}, {'id': 28}, {'id': 92}]},
#          {'id': 31},
#          {'id': 60},
#          {'id': 29}]},
#        {'id': 87},
#        {'id': 57},
#        {'id': 30}]},
#      {'id': 148,
#       'children': [{'id': 135,
#         'children': [{'id': 122,
#           'children': [{'id': 36}, {'id': 54}, {'id': 66}]},
#          {'id': 129, 'children': [{'id': 39}, {'id': 40}]},
#          {'id': 68},
#          {'id': 44}]},
#        {'id': 137,
#         'children': [{'id': 126,
#           'children': [{'id': 35}, {'id': 55}, {'id': 5}]},
#          {'id': 134,
#           'children': [{'id': 121,
#             'children': [{'id': 77}, {'id': 45}, {'id': 50}]},
#            {'id': 88}]},
#          {'id': 32}]}]}]},
#    {'id': 151,
#     'children': [{'id': 125,
#       'children': [{'id': 27}, {'id': 69}, {'id': 56}, {'id': 26}]},
#      {'id': 144,
#       'children': [{'id': 118,
#         'children': [{'id': 13}, {'id': 19}, {'id': 98}]},
#        {'id': 128,
#         'children': [{'id': 109, 'children': [{'id': 34}, {'id': 18}]},
#          {'id': 15},
#          {'id': 96},
#          {'id': 93}]},
#        {'id': 132, 'children': [{'id': 42}, {'id': 85}]}]}]}]},
#  'gamestarttime': 1669909597.0503192,
#  'gameendtime': 1669910197.0503192}
